# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielDialektico/dialektico-machine-learning-practices/blob/main/notebooks/Otros/Tutorial_API_de_Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://dialektico.com/wp-content/uploads/2023/03/MiniLogoW4.png" alt="Dialéktico Logo" />

# %% [markdown]
# # **Consumo de API de Spotify con Python usando Spotipy 🎼**

# %% [markdown]
# # **Introducción**

# %% [markdown]
# En este **notebook** pondremos en práctica cómo consumir la **API** de **Spotify** usando la librería Spotipy de Python, donde obtendremos datos de canciones y artistas, y los ordenaremos en formato tabular para finalmente almacenar la información en un CSV.
#
# Este notebook es parte del [tutorial de cómo consumir la API de Spotify con Python](https://dialektico.com/tutorial-api-spotify-python/), donde se pueden hallar instrucciones más detalladas.
#
# <br>
# <center><img src="https://dialektico.com/wp-content/uploads/2025/01/APIS_colab.jpg" width="300" /></center>
#
# <br>
# <center><img src="https://dialektico.com/wp-content/uploads/2025/01/APIS_Colab_obj.jpg" width="300" /></center>

# %% [markdown]
# <br>

# %% [markdown]
# # **Instalación de librerías**

# %% [markdown]
# Instalamos la librerías:

# %% [markdown]
# ***Nota*:** *Las instalaciones se realizan a pesar de que algunas librerías ya están integradas de forma nativa en Colab, esto para asegurar que el Notebook no presente problemas de ejecución si se dan cambios de sintaxis entre versiones de librerías.*

# %%
# !pip install pandas==2.2.2
# !pip install tqdm==4.67.1
# !pip install spotipy==2.25.0
# Out:
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting spotipy==2.25.0
#   Downloading spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting redis>=3.5.3 (from spotipy==2.25.0)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from spotipy==2.25.0) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from spotipy==2.25.0) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy==2.25.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy==2.25.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy==2.25.0) (2024.12.14)
# Downloading spotipy-2.25.0-py3-none-any.whl (30 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.2.1 spotipy-2.25.0

# %% [markdown]
# <br>

# %% [markdown]
# # **Se añaden las credenciales de autenticación**

# %% [markdown]
# Se declaran las variables con las **credenciales** ([ver tutorial](https://dialektico.com/tutorial-api-spotify-python/)).

# %%
# Se importan las librerías necesarias.
import warnings
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from tqdm import tqdm

# Se filtran las advertencias.
warnings.filterwarnings('ignore')

# Se declara el ID del cliente.
client_id = '1ac2cc06cf774a9caa548b37a4e22ddf'

# Se declara el valor del secret client.
client_secret = '401d357f92584b80b26f40f9f8664eaa'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)

# %% [markdown]
# <br>

# %% [markdown]
# # **Usando Spotipy para extraer datos**

# %% [markdown]
# Comenzamos creando el objeto que nos permitirá consumir los endpoints de la API.

# %%
# Se crea el cliente que se utilizará para consumir la API.
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Probamos utilizando la función search, la cual permite obtener información del catálogo de Spotify sobre **álbumes**, **artistas**,** listas de reproducción**, **canciones**, **programas**, **episodios** o **audiolibros** que coincidan con una cadena de palabras clave (es decir, buscará y traerá información sobre algún elemento especificado).
#
# Visualizamos el formato en el que se entrega la información, haciendo una búsqueda de datos de la agrupación **Blackpink**.

# %%
# Se busca información sobre Blackpink.
result = sp.search(q='Blackpink', type='artist', limit=1)

# Se imprime el resultado.
result
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Blackpink&type=artist',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Blackpink&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 833,
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'followers': {'href': None, 'total': 52784037},
#     'genres': ['k-pop'],
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebc9690bc711d04b3d4fd4b87c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174c9690bc711d04b3d4fd4b87c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178c9690bc711d04b3d4fd4b87c',
#       'height': 160,
#       'width': 160}],
#     'name': 'BLACKPINK',
#     'popularity': 78,
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}]}}

# %% [markdown]
# Ahora accedemos a un elemento en particular del diccionario, en este caso, al **número total de seguidores** del grupo en la plataforma:

# %%
# Se imprime el número de seguidores de Blackpink.
result['artists']['items'][0]['followers']['total']
# Out:
# 52784037

# %% [markdown]
# Obtenemos el top de 10 canciones más populares de la banda utilizando el método [artist_top_tracks](https://spotipy.readthedocs.io/en/2.22.1/#spotipy.client.Spotify.artist_top_tracks):

# %%
# Se busca información sobre Blackpink y se obtiene su ID de artista.
result = sp.search(q='Blackpink', type='artist', limit=1)
blackpink_id = result['artists']['items'][0]['id']

# Se obtienen las 10 canciones más escuchadas de Blackpink.
results = sp.artist_top_tracks(blackpink_id)

# Se imprime el nombre de las canciones.
for track in results['tracks']:
    print(track['name'])
# Out:
# Pink Venom
# Shut Down
# How You Like That
# Kill This Love
# As If It's Your Last
# Lovesick Girls
# Kiss and Make Up
# DDU-DU DDU-DU
# Typa Girl
# Pretty Savage

# %% [markdown]
# <br>

# %% [markdown]
# ## **Extrayendo datos en tablas**

# %% [markdown]
# Creamos una función para la extracción de 50 canciones de un **género** definido (parámetro de entrada), sus características, y ordena la información en un dataFrame de **Pandas**:

# %%
def get_tracks_by_genre(genre):
    """
    Función que obtiene información de 50 canciones de un género musical de
    Spotify y organiza la información de un Pandas dataframe.
    """

    # Se buscan 50 canciones del género especificado.
    results = sp.search(q=f'genre:{genre}', type='track', limit=50)

    # Se extrane los IDs de las canciones.
    track_ids = [track['id'] for track in results['tracks']['items']]

    # Se obtienen detalles de las canciones.
    tracks_info = sp.tracks(tracks=track_ids)

    # Se crea una lista para almacenar los datos.
    track_data = []

    # Se obtienen los datos de cada canción y se añaden a la lista.
    for track in tracks_info['tracks']:
        track_data.append({
            'genre': genre,
            'name': track['name'],
            'artists_name': ', '.join([artist['name'] for artist in track['artists']]),  # Si hay varios artistas
            'album_name': track['album']['name'],
            'album_release_date': track['album']['release_date'],
            'duration_ms': track['duration_ms'],
            'popularity': track['popularity'],
            'track_number': track['track_number'],
            'uri': track['uri']
        })

    # Se convierte la lista en un DataFrame de pandas.
    df = pd.DataFrame(track_data)

    return df

# %% [markdown]
# Probamos la función con el género **Rock**:

# %%
# Ejemplo de uso con el género 'rock'.
genre = "rock"
get_tracks_by_genre(genre)
# Out:
#    genre                                      name  \
# 0   rock                           Sweater Weather
# 1   rock                                       505
# 2   rock         Rockin' Around The Christmas Tree
# 3   rock                            Mr. Brightside
# 4   rock                    Dreams - 2004 Remaster
# 5   rock                         Take Me to Church
# 6   rock                          I Wanna Be Yours
# 7   rock                       Cigarette Daydreams
# 8   rock                            Last Christmas
# 9   rock                                     Creep
# 10  rock                            Feel Good Inc.
# 11  rock                                 Work Song
# 12  rock                        No. 1 Party Anthem
# 13  rock                                      Iris
# 14  rock                                 Too Sweet
# 15  rock                           One Last Breath
# 16  rock         Everybody Wants To Rule The World
# 17  rock                                 Evergreen
# 18  rock                              Daddy Issues
# 19  rock                                  Everlong
# 20  rock      Don't Stop Believin' (2022 Remaster)
# 21  rock                The Less I Know The Better
# 22  rock                                    Linger
# 23  rock                         How You Remind Me
# 24  rock                                      Numb
# 25  rock                                Space Song
# 26  rock                           Come As You Are
# 27  rock                                  Santeria
# 28  rock                                   Riptide
# 29  rock                           Pumped Up Kicks
# 30  rock                     Every Breath You Take
# 31  rock                        For the First Time
# 32  rock                                In the End
# 33  rock                                The Middle
# 34  rock                   Smells Like Teen Spirit
# 35  rock                                  Softcore
# 36  rock                                Kryptonite
# 37  rock                                 Too Sweet
# 38  rock                          Do I Wanna Know?
# 39  rock                          My Kind of Woman
# 40  rock                      Animal I Have Become
# 41  rock                               Someone New
# 42  rock                           One Step Closer
# 43  rock                                Can't Stop
# 44  rock                        You Get Me So High
# 45  rock                                    Africa
# 46  rock                               Uptown Girl
# 47  rock  Why'd You Only Call Me When You're High?
# 48  rock              Ain't No Rest for the Wicked
# 49  rock                              Stressed Out
#
#                                          album_name album_release_date  \
# 0                                       I Love You.         2013-04-22
# 1      Favourite Worst Nightmare (Standard Version)         2007-04-24
# 2                   Merry Christmas From Brenda Lee         1964-10-19
# 3                                          Hot Fuss               2004
# 4                            Rumours (Super Deluxe)         1977-02-04
# 5                         Hozier (Expanded Edition)         2014-09-19
# 6                                                AM         2013-09-09
# 7                                        Melophobia         2013-10-08
# 8                                    LAST CHRISTMAS         1984-11-29
# 9                                       Pablo Honey         1993-02-22
# 10                                       Demon Days         2005-05-23
# 11                        Hozier (Expanded Edition)         2014-09-19
# 12                                               AM         2013-09-09
# 13                                Dizzy up the Girl               1998
# 14                          Unreal Unearth: Unaired         2024-08-19
# 15                                        Weathered         2001-01-01
# 16  Songs From The Big Chair (Super Deluxe Edition)         1985-02-25
# 17                                             RMCM         2017-05-17
# 18                                       Wiped Out!         2015-10-30
# 19                         The Colour And The Shape         1997-05-20
# 20                           Escape (2022 Remaster)         1981-07-17
# 21                                         Currents         2015-07-17
# 22     Everybody Else Is Doing It, So Why Can't We?         1993-03-01
# 23                                   Silver Side Up         2001-09-11
# 24                                          Meteora         2003-09-16
# 25                                Depression Cherry         2015-08-28
# 26                           Nevermind (Remastered)         1991-09-26
# 27                                          Sublime         1996-07-30
# 28            Dream Your Life Away (Deluxe Edition)         2014-08-05
# 29                                          Torches         2011-05-23
# 30                  Synchronicity (Remastered 2003)         1983-06-17
# 31                                     This Old Dog         2017-05-05
# 32                    Hybrid Theory (Bonus Edition)               2000
# 33                                   Bleed American         2001-07-17
# 34                           Nevermind (Remastered)         1991-09-26
# 35  Hard To Imagine The Neighbourhood Ever Changing         2018-11-02
# 36                                  The Better Life               2000
# 37                                          Unheard         2024-03-22
# 38                                               AM         2013-09-09
# 39                                                2         2012-10-16
# 40                                            One-X         2006-06-25
# 41                        Hozier (Expanded Edition)         2014-09-19
# 42                    Hybrid Theory (Bonus Edition)               2000
# 43                      By the Way (Deluxe Edition)         2002-07-09
# 44  Hard To Imagine The Neighbourhood Ever Changing         2018-11-02
# 45                                          Toto IV         1982-04-08
# 46                                  An Innocent Man         1983-08-08
# 47                                               AM         2013-09-09
# 48             Cage The Elephant (Expanded Edition)         2009-03-24
# 49                                       Blurryface         2015-05-15
#
#                      artists_name  duration_ms  popularity  track_number  \
# 0               The Neighbourhood       240400          89             4
# 1                  Arctic Monkeys       253586          79            12
# 2                      Brenda Lee       126266          86             1
# 3                     The Killers       222973          86             2
# 4                   Fleetwood Mac       257800          85             2
# 5                          Hozier       241693          79             1
# 6                  Arctic Monkeys       183956          90            12
# 7               Cage The Elephant       208760          79            10
# 8                           Wham!       262960          86             1
# 9                       Radiohead       238640          86             2
# 10                       Gorillaz       222640          85             6
# 11                         Hozier       229720          78             9
# 12                 Arctic Monkeys       243131          87             6
# 13              The Goo Goo Dolls       289533          86            11
# 14                         Hozier       251424          78             1
# 15                          Creed       238240          80             5
# 16                Tears For Fears       251488          85             3
# 17  Richy Mitch & The Coal Miners        87000          83             1
# 18              The Neighbourhood       260173          84             6
# 19                   Foo Fighters       250546          81            11
# 20                        Journey       249600          84             1
# 21                    Tame Impala       216320          83             7
# 22                The Cranberries       274706          82             7
# 23                     Nickelback       223840          83             2
# 24                    Linkin Park       187520          86            13
# 25                    Beach House       320466          76             3
# 26                        Nirvana       218920          77             3
# 27                        Sublime       182746          78             6
# 28                      Vance Joy       204280          82             4
# 29              Foster The People       239600          83             2
# 30                     The Police       253920          88             7
# 31                    Mac DeMarco       182306          80             4
# 32                    Linkin Park       216880          85             8
# 33                Jimmy Eat World       165853          80             3
# 34                        Nirvana       301920          76             1
# 35              The Neighbourhood       206280          84             5
# 36                   3 Doors Down       233933          79             1
# 37                         Hozier       251424          76             1
# 38                 Arctic Monkeys       272394          85             1
# 39                    Mac DeMarco       190845          80             8
# 40               Three Days Grace       231400          77             3
# 41                         Hozier       222813          75             4
# 42                    Linkin Park       157333          82             2
# 43          Red Hot Chili Peppers       269000          83             7
# 44              The Neighbourhood       153000          81             9
# 45                           TOTO       295893          84            10
# 46                     Billy Joel       197706          82             6
# 47                 Arctic Monkeys       161123          84             9
# 48              Cage The Elephant       175493          75             3
# 49              Twenty One Pilots       202333          84             2
#
#                                      uri
# 0   spotify:track:2QjOHCTQ1Jl3zawyYOpxh6
# 1   spotify:track:58ge6dfP91o9oXMzq3XkIS
# 2   spotify:track:2EjXfH91m7f8HiJN1yQg97
# 3   spotify:track:003vvx7Niy0yvhvHt4a68B
# 4   spotify:track:0ofHAoxe9vBkTCp2UQIavz
# 5   spotify:track:1CS7Sd1u5tWkstBhpssyjP
# 6   spotify:track:5XeFesFbtLpXzIVDNQP22n
# 7   spotify:track:2tznHmp70DxMyr2XhWLOW0
# 8   spotify:track:2FRnf9qhLbvw8fu4IBXx78
# 9   spotify:track:70LcF31zb1H0PyJoS1Sx1r
# 10  spotify:track:0d28khcov6AiegSCpG5TuT
# 11  spotify:track:5TgEJ62DOzBpGxZ7WRsrqb
# 12  spotify:track:5TTGoX70AFrTvuEtqHK37S
# 13  spotify:track:6Qyc6fS4DsZjB2mRW9DsQs
# 14  spotify:track:76JKIsdKrAfWUMjaA0u7v5
# 15  spotify:track:42T2QQv3xgBlpQxaSP7lnK
# 16  spotify:track:4RvWPyQ5RL0ao9LPZeSouE
# 17  spotify:track:6me7F0aaZjwDo6RJ5MrfBD
# 18  spotify:track:5E30LdtzQTGqRvNd7l6kG5
# 19  spotify:track:5UWwZ5lm5PKu6eKsHAGxOk
# 20  spotify:track:5RKQ5NdjSh2QzD4MaunT91
# 21  spotify:track:6K4t31amVTZDgR3sKmwUJJ
# 22  spotify:track:0gEyKnHvgkrkBM6fbeHdwK
# 23  spotify:track:0gmbgwZ8iqyMPmXefof8Yf
# 24  spotify:track:2nLtzopw4rPReszdYBJU6h
# 25  spotify:track:7H0ya83CMmgFcOhw0UB6ow
# 26  spotify:track:4P5KoWXOxwuobLmHXLMobV
# 27  spotify:track:2hnMS47jN0etwvFPzYk11f
# 28  spotify:track:2uXlHCUbq9OMUwx3hrk06o
# 29  spotify:track:7w87IxuO7BDcJ3YUqCyMTT
# 30  spotify:track:1JSTJqkT5qHq8MDJnJbRE1
# 31  spotify:track:2R4AlwtrrkMaRKojcTIzmL
# 32  spotify:track:60a0Rd6pjrkxjPbaKzXjfq
# 33  spotify:track:6GG73Jik4jUlQCkKg9JuGO
# 34  spotify:track:5ghIJDpPoe3CfHMGu71E6T
# 35  spotify:track:2K7xn816oNHJZ0aVqdQsha
# 36  spotify:track:6ZOBP3NvffbU4SZcrnt1k6
# 37  spotify:track:4IadxL6BUymXlh8RCJJu7T
# 38  spotify:track:5FVd6KXrgO9B3JPmC8OPst
# 39  spotify:track:6jgkEbmQ2F2onEqsEhiliL
# 40  spotify:track:56sk7jBpZV0CD31G9hEU3b
# 41  spotify:track:2DNXgvkyv35vTWvdgjs7qn
# 42  spotify:track:3K4HG9evC7dg3N0R9cYqk4
# 43  spotify:track:3ZOEytgrvLwQaqXreDs2Jx
# 44  spotify:track:7zwn1eykZtZ5LODrf7c0tS
# 45  spotify:track:2374M0fQpWi3dLnB54qaLX
# 46  spotify:track:5zA8vzDGqPl2AzZkEYQGKh
# 47  spotify:track:086myS9r57YsLbJpU0TgK9
# 48  spotify:track:3Pzh926pXggbMe2ZpXyMV7
# 49  spotify:track:3CRDbSIZ4r5MsZ0YwxuEkn

# %% [markdown]
# **Nota**: una lista de los géneros disponibles se puede consultar en https://everynoise.com/everynoise1d-reggaetoncristiano.html

# %% [markdown]
# Ahora creamos un bucle que obtenga estos datos para cada género especificado de una **lista**, y concatenamos las **tablas** resultantes para obtener un conjunto de datos:

# %%
# Se importa una librería para la generación de una barra de progreso.
from tqdm import tqdm

# Se crea una lista con los géneros musicales deseados.
genres_list = ['world-music', 'salsa', 'rock-n-roll', 'reggae', 'reggaeton', 'pop', 'black-metal', 'k-pop', 'hip-hop', 'electronic']

# Se itera sobre esta lista utilizando sus elementos como entradas de la función creada.
tables = []

for item in tqdm(genres_list, desc = 'Creando conjunto de datos:'):
  table = get_tracks_by_genre(item)
  tables.append(table)

# Se concatenan las tablas y se imprime el resultado.
dataset = pd.concat(tables)
dataset
# Out:
# Creando conjunto de datos:: 100%|██████████| 10/10 [00:05<00:00,  1.84it/s]
#           genre                          name  \
# 0   world-music  Oceans (Where Feet May Fail)
# 1   world-music                God Only Knows
# 2   world-music     So Will I (100 Billion X)
# 3   world-music            For God Is With Us
# 4   world-music          Lead Me To The Cross
# ..          ...                           ...
# 45   electronic                       Tsunami
# 46   electronic                         Steal
# 47   electronic                  Bfg Division
# 48   electronic              Six Days - Remix
# 49   electronic                    Praise You
#
#                                            album/name album/release_date  \
# 0                               Zion (Deluxe Edition)         2013-02-26
# 1                                      Burn The Ships         2018-10-05
# 2                                              Wonder         2017-06-09
# 3                            What Are We Waiting For?         2022-03-11
# 4                                    All Of The Above               2007
# ..                                                ...                ...
# 45                                            Tsunami         2013-09-02
# 46                                          Portraits         2015-06-01
# 47                    Doom (Original Game Soundtrack)         2016-09-28
# 48  The Fast And The Furious: Tokyo Drift (Origina...         2006-06-20
# 49                        You've Come A Long Way Baby         1998-01-01
#
#                                   artists/name  duration_ms  popularity  \
# 0                        Hillsong UNITED, TAYA       535962          66
# 1                           for KING & COUNTRY       229760          66
# 2   Hillsong UNITED, Benjamin William Hastings       411000          62
# 3                           for KING & COUNTRY       196846          63
# 4           Hillsong UNITED, Brooke Ligertwood       258626          58
# ..                                         ...          ...         ...
# 45                             DVBBS, Borgeous       236706          65
# 46                 Maribou State, Holly Walker       219945          67
# 47                                 Mick Gordon       506762          60
# 48                          DJ Shadow, Mos Def       232000          67
# 49                                 Fatboy Slim       323240          54
#
#     track_number                                   uri
# 0              4  spotify:track:5Mw9bXG1dLNhbjofkVS2oR
# 1              3  spotify:track:4ElNxglBjcrASiGn58t9Jm
# 2              4  spotify:track:1ed3wNCecRIp6SugyR0w2J
# 3              5  spotify:track:0CQPPHjPpG4kAzvfOcKvh8
# 4              6  spotify:track:7i2ZmmyLzE7NcFAJl30mKY
# ..           ...                                   ...
# 45             1  spotify:track:0vZCG0H9KhtU7K8MEUVAoV
# 46             4  spotify:track:0pAiyIHt9DyHOjWgF41kp6
# 47            11  spotify:track:4COR2ZPEyUn0lsbAouRWxA
# 48             2  spotify:track:5j3QqRGflS4o5jbsFSwKW1
# 49             9  spotify:track:3yGy1JYz3zQKlxSgjgpQqX
#
# [500 rows x 9 columns]

# %% [markdown]
# Por último se descarga en formato CSV:

# %%
# Se convierte a formato CSV.
dataset.to_csv('dataset.csv', index=False)

# Se descarga el CSV.
from google.colab import files
files.download('dataset.csv')

# %% [markdown]
# O en formato XLS:

# %%
# Se convierte a formato Excel.
dataset.to_excel('dataset.xlsx', index=False)

# Se descarga el Excel.
from google.colab import files
files.download('dataset.xlsx')

# %% [markdown]
# No olvides que puedes encontrar más tópicos como este en https://dialektico.com/.

# %% [markdown]
# ▶ [Regresar al tutorial](https://dialektico.com/tutorial-api-spotify-python/) 📕

# %% [markdown]
# <br>

# %%
# Dialektico Machine learning practices © 2024 by Daniel Antonio García Escobar
# is licensed under CC BY-NC 4.0. To view a copy of this license,
# visit https://creativecommons.org/licenses/by-nc/4.0/

# Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International
# Public License
